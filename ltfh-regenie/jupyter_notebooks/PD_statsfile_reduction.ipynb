# %%
library(data.table)

# %%
data <- fread("../PD_ukb_step2_BT_ltfh.regenie.corrected")

# %%
data
# Out:
#          CHROM GENPOS   ID                               ALLELE0
# 1        1     10177    rs367896724                      A
# 2        1     10235    rs540431307                      T
# 3        1     10352    rs201106462                      T
# 4        1     10511    rs534229142                      G
# 5        1     10539    rs537182016                      C
# 6        1     10616    1:10616_CCGCCGTTGCAAAGGCGCGCCG_C CCGCCGTTGCAAAGGCGCGCCG
# 7        1     10642    rs558604819                      G
# 8        1     11008    rs575272151                      C
# 9        1     11012    rs544419019                      C
# 10       1     11063    rs561109771                      T
# 11       1     13011    rs574746232                      T
# 12       1     13110    rs540538026                      G
# 13       1     13116    rs62635286                       T
# 14       1     13118    rs62028691                       A
# ...

# %%
subdata <- data[data$LOG10P > 1.44]

# %%
length(subdata$ID)
# Out:
# [1] 1014228

# %%
fwrite(subdata,"../PD_ukb_step2_BT_ltfh.regenie.corrected.reduced",sep=' ')

# %%
subdata
# Out:
#         CHROM GENPOS   ID               ALLELE0 ALLELE1 A1FREQ      INFO
# 1       1      79807   rs551120284      G       A       5.12350e-05 0.697348
# 2       1     129672   rs528833435      A       G       1.18492e-04 0.584391
# 3       1     601158   1:601158_GAGTA_G GAGTA   G       8.54688e-04 0.827805
# 4       1     720026   rs553652309      C       T       2.03160e-05 0.999313
# 5       1     720663   rs552229741      T       C       3.57367e-04 0.528736
# 6       1     742594   rs551006412      C       T       1.72737e-03 0.642528
# 7       1     755223   rs564409257      T       C       5.71687e-05 0.567079
# 8       1     758324   rs3131955        T       C       9.99038e-01 0.825351
# 9       1     768253   rs2977608        A       C       7.61716e-01 0.995274
# 10      1     770416   rs141970171      C       A       5.65365e-05 0.667530
# 11      1     793887   rs549388574      T       TG      6.14914e-05 0.630859
# ...
