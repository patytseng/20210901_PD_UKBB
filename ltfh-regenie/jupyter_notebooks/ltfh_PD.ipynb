# %%
library(data.table)
library(ggplot2)

# %%
source('/gpfs/home/ptseng/LTFH/assign_ltfh.R')

# %%
raw_out_path <- '../regenie_input/PD_pheno_raw.txt'

# %%
data <- fread(raw_out_path,sep=' ')

# %%
for (field in c(
    "f.40001.0.0", "f.40001.1.0",
    "f.40002.0.1",  "f.40002.0.2",  "f.40002.0.3",  "f.40002.0.4",  "f.40002.0.5",  "f.40002.0.6",  "f.40002.0.7",  "f.40002.0.8",  "f.40002.0.9", 
    "f.40002.0.10", "f.40002.0.11", "f.40002.0.12", "f.40002.0.13", "f.40002.0.14", 
    "f.40002.1.1",  "f.40002.1.2",  "f.40002.1.3",  "f.40002.1.4",  "f.40002.1.5",  "f.40002.1.6",  "f.40002.1.7",  "f.40002.1.8",  "f.40002.1.9", 
    "f.40002.1.10", "f.40002.1.11", "f.40002.1.12", "f.40002.1.13", "f.40002.1.14"
)){
    set(data, j = field, value = as.character(data[[field]]))
}
for (field in c(
    "f.41203.0.0",  "f.41203.0.1",  "f.41203.0.2",  "f.41203.0.3",  "f.41203.0.4",  "f.41203.0.5",  "f.41203.0.6",  "f.41203.0.7",  "f.41203.0.8",  "f.41203.0.9", 
    "f.41203.0.10", "f.41203.0.11", "f.41203.0.12", "f.41203.0.13", "f.41203.0.14", "f.41203.0.15", "f.41203.0.16", "f.41203.0.17", "f.41203.0.18", "f.41203.0.19", 
    "f.41203.0.20", "f.41203.0.21", "f.41203.0.22", "f.41203.0.23", "f.41203.0.24", "f.41203.0.25", "f.41203.0.26", "f.41203.0.27",
    "f.41205.0.0",  "f.41205.0.1",  "f.41205.0.2",  "f.41205.0.3",  "f.41205.0.4",  "f.41205.0.5",  "f.41205.0.6",  "f.41205.0.7",  "f.41205.0.8",  "f.41205.0.9", 
    "f.41205.0.10", "f.41205.0.11", "f.41205.0.12", "f.41205.0.13", "f.41205.0.14", "f.41205.0.15", "f.41205.0.16", "f.41205.0.17", "f.41205.0.18", "f.41205.0.19", 
    "f.41205.0.20", "f.41205.0.21", "f.41205.0.22", "f.41205.0.23", "f.41205.0.24", "f.41205.0.25", "f.41205.0.26", "f.41205.0.27", "f.41205.0.28", "f.41205.0.29"
)){
    set(data, j = field, value = as.character(data[[field]]))
}
for (field in c(
    "f.41202.0.0",  "f.41202.0.1",  "f.41202.0.2",  "f.41202.0.3",  "f.41202.0.4",  "f.41202.0.5",  "f.41202.0.6",  "f.41202.0.7",  "f.41202.0.8",  "f.41202.0.9", 
    "f.41202.0.10", "f.41202.0.11", "f.41202.0.12", "f.41202.0.13", "f.41202.0.14", "f.41202.0.15", "f.41202.0.16", "f.41202.0.17", "f.41202.0.18", "f.41202.0.19", 
    "f.41202.0.20", "f.41202.0.21", "f.41202.0.22", "f.41202.0.23", "f.41202.0.24", "f.41202.0.25", "f.41202.0.26", "f.41202.0.27", "f.41202.0.28", "f.41202.0.29", 
    "f.41202.0.30", "f.41202.0.31", "f.41202.0.32", "f.41202.0.33", "f.41202.0.34", "f.41202.0.35", "f.41202.0.36", "f.41202.0.37", "f.41202.0.38", "f.41202.0.39", 
    "f.1883.0.0", "f.1883.1.0", "f.1883.2.0", "f.1883.3.0"
)) {
    set(data, j = field, value = as.numeric(data[[field]]))
}
for (field in c(
    "f.20111.0.0", "f.20111.0.1", "f.20111.0.2", "f.20111.0.3", "f.20111.0.4", "f.20111.0.5", "f.20111.0.6", "f.20111.0.7", "f.20111.0.8", "f.20111.0.9", "f.20111.0.10", "f.20111.0.11", 
    "f.20111.1.0", "f.20111.1.1", "f.20111.1.2", "f.20111.1.3", "f.20111.1.4", "f.20111.1.5", "f.20111.1.6", "f.20111.1.7", "f.20111.1.8", "f.20111.1.9", "f.20111.1.10", "f.20111.1.11", 
    "f.20111.2.0", "f.20111.2.1", "f.20111.2.2", "f.20111.2.3", "f.20111.2.4", "f.20111.2.5", "f.20111.2.6", "f.20111.2.7", "f.20111.2.8", "f.20111.2.9", "f.20111.2.10", "f.20111.2.11", 
    "f.20111.3.0", "f.20111.3.1", "f.20111.3.2", "f.20111.3.3", "f.20111.3.4", "f.20111.3.5", "f.20111.3.6", "f.20111.3.7", "f.20111.3.8", "f.20111.3.9", "f.20111.3.10", "f.20111.3.11"
)) {
    set(data, j = field, value = as.numeric(data[[field]]))
}

# %%
head(data)
# Out:
#   FID     IID     f.1873.0.0 f.1873.1.0 f.1873.2.0 f.1873.3.0 f.1883.0.0
# 1 1000011 1000011 1          NA         NA         NA         1
# 2 1000026 1000026 0          NA         NA         NA         0
# 3 1000032 1000032 0          NA         NA         NA         2
# 4 1000044 1000044 1          NA         NA         NA         0
# 5 1000058 1000058 1          NA         NA         NA         1
# 6 1000060 1000060 0          NA         NA         NA         0
#   f.1883.1.0 f.1883.2.0 f.1883.3.0 ⋯ f.41205.0.20 f.41205.0.21 f.41205.0.22
# 1 NA         NA         NA         ⋯ NA           NA           NA
# 2 NA         NA         NA         ⋯ NA           NA           NA
# 3 NA         NA         NA         ⋯ NA           NA           NA
# 4 NA         NA         NA         ⋯ NA           NA           NA
# 5 NA         NA         NA         ⋯ NA           NA           NA
# 6 NA         NA         NA         ⋯ NA           NA           NA
# ...

# %%
subdata <- data.table(data[,'IID'])

# %%
iteration_1 <- TRUE
PD_catcher <- data.frame(IID=data[,'IID'],PD=FALSE)
na_catcher <- data.frame(IID=data[,'IID'],na=TRUE)

for (field in c(
    "f.40001.0.0", "f.40001.1.0",
    "f.40002.0.1",  "f.40002.0.2",  "f.40002.0.3",  "f.40002.0.4",  "f.40002.0.5",  "f.40002.0.6",  "f.40002.0.7",  "f.40002.0.8",  "f.40002.0.9", 
    "f.40002.0.10", "f.40002.0.11", "f.40002.0.12", "f.40002.0.13", "f.40002.0.14", 
    "f.40002.1.1",  "f.40002.1.2",  "f.40002.1.3",  "f.40002.1.4",  "f.40002.1.5",  "f.40002.1.6",  "f.40002.1.7",  "f.40002.1.8",  "f.40002.1.9", 
    "f.40002.1.10", "f.40002.1.11", "f.40002.1.12", "f.40002.1.13", "f.40002.1.14"
)){
    temp <- data[ , ..field] == "G20"
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

for (field in c(
    "f.41203.0.0",  "f.41203.0.1",  "f.41203.0.2",  "f.41203.0.3",  "f.41203.0.4",  "f.41203.0.5",  "f.41203.0.6",  "f.41203.0.7",  "f.41203.0.8",  "f.41203.0.9", 
    "f.41203.0.10", "f.41203.0.11", "f.41203.0.12", "f.41203.0.13", "f.41203.0.14", "f.41203.0.15", "f.41203.0.16", "f.41203.0.17", "f.41203.0.18", "f.41203.0.19", 
    "f.41203.0.20", "f.41203.0.21", "f.41203.0.22", "f.41203.0.23", "f.41203.0.24", "f.41203.0.25", "f.41203.0.26", "f.41203.0.27",
    "f.41205.0.0",  "f.41205.0.1",  "f.41205.0.2",  "f.41205.0.3",  "f.41205.0.4",  "f.41205.0.5",  "f.41205.0.6",  "f.41205.0.7",  "f.41205.0.8",  "f.41205.0.9", 
    "f.41205.0.10", "f.41205.0.11", "f.41205.0.12", "f.41205.0.13", "f.41205.0.14", "f.41205.0.15", "f.41205.0.16", "f.41205.0.17", "f.41205.0.18", "f.41205.0.19", 
    "f.41205.0.20", "f.41205.0.21", "f.41205.0.22", "f.41205.0.23", "f.41205.0.24", "f.41205.0.25", "f.41205.0.26", "f.41205.0.27", "f.41205.0.28", "f.41205.0.29"
)){
    temp <- data[ , ..field] == "3320"
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

for (field in c(
    "f.41202.0.0",  "f.41202.0.1",  "f.41202.0.2",  "f.41202.0.3",  "f.41202.0.4",  "f.41202.0.5",  "f.41202.0.6",  "f.41202.0.7",  "f.41202.0.8",  "f.41202.0.9", 
    "f.41202.0.10", "f.41202.0.11", "f.41202.0.12", "f.41202.0.13", "f.41202.0.14", "f.41202.0.15", "f.41202.0.16", "f.41202.0.17", "f.41202.0.18", "f.41202.0.19", 
    "f.41202.0.20", "f.41202.0.21", "f.41202.0.22", "f.41202.0.23", "f.41202.0.24", "f.41202.0.25", "f.41202.0.26", "f.41202.0.27", "f.41202.0.28", "f.41202.0.29", 
    "f.41202.0.30", "f.41202.0.31", "f.41202.0.32", "f.41202.0.33", "f.41202.0.34", "f.41202.0.35", "f.41202.0.36", "f.41202.0.37", "f.41202.0.38", "f.41202.0.39", 
    "f.41202.0.40", "f.41202.0.41", "f.41202.0.42", "f.41202.0.43", "f.41202.0.44", "f.41202.0.45", "f.41202.0.46", "f.41202.0.47", "f.41202.0.48", "f.41202.0.49", 
    "f.41202.0.50", "f.41202.0.51", "f.41202.0.52", "f.41202.0.53", "f.41202.0.54", "f.41202.0.55", "f.41202.0.56", "f.41202.0.57", "f.41202.0.58", "f.41202.0.59", 
    "f.41202.0.60", "f.41202.0.61", "f.41202.0.62", "f.41202.0.63", "f.41202.0.64", "f.41202.0.65",
    "f.41204.0.150", "f.41204.0.151", "f.41204.0.152", "f.41204.0.153", "f.41204.0.154", "f.41204.0.155", "f.41204.0.156", "f.41204.0.157", "f.41204.0.158", "f.41204.0.159", 
    "f.41204.0.160", "f.41204.0.161", "f.41204.0.162", "f.41204.0.163", "f.41204.0.164", "f.41204.0.165", "f.41204.0.166", "f.41204.0.167", "f.41204.0.168", "f.41204.0.169", 
    "f.41204.0.170", "f.41204.0.171", "f.41204.0.172", "f.41204.0.173", "f.41204.0.174", "f.41204.0.175", "f.41204.0.176", "f.41204.0.177", "f.41204.0.178", "f.41204.0.179", 
    "f.41204.0.180", "f.41204.0.181", "f.41204.0.182", "f.41204.0.183"
)){
    temp <- (data[ , ..field] == "G20")  | (data[ , ..field] == "F023")
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

na_catcher$na[na_catcher$na==TRUE] <- NA

subdata[,'CHILD_STATUS'] <- as.integer(PD_catcher$PD | na_catcher$na)

# %%
length(subdata[subdata$CHILD_STATUS == 1,]$IID)/length(subdata$IID)
# Out:
# [1] 0.00668073

# %%
iteration_1 <- TRUE
PD_catcher <- data.frame(IID=data[,'IID'],PD=FALSE)
na_catcher <- data.frame(IID=data[,'IID'],na=TRUE)

for (field in c(
    "f.20107.0.0", "f.20107.0.1", "f.20107.0.2", "f.20107.0.3", "f.20107.0.4", "f.20107.0.5", "f.20107.0.6", "f.20107.0.7", "f.20107.0.8", "f.20107.0.9", 
    "f.20107.1.0", "f.20107.1.1", "f.20107.1.2", "f.20107.1.3", "f.20107.1.4", "f.20107.1.5", "f.20107.1.6", "f.20107.1.7", "f.20107.1.8", "f.20107.1.9", 
    "f.20107.2.0", "f.20107.2.1", "f.20107.2.2", "f.20107.2.3", "f.20107.2.4", "f.20107.2.5", "f.20107.2.6", "f.20107.2.7", "f.20107.2.8", "f.20107.2.9", 
    "f.20107.3.0", "f.20107.3.1", "f.20107.3.2", "f.20107.3.3", "f.20107.3.4", "f.20107.3.5", "f.20107.3.6", "f.20107.3.7", "f.20107.3.8", "f.20107.3.9"
)) {
    temp <- (data[ , ..field] == 11)
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

na_catcher$na[na_catcher$na==TRUE] <- NA

subdata[,'P1_STATUS'] <- as.integer(PD_catcher$PD | na_catcher$na)

# %%
iteration_1 <- TRUE
PD_catcher <- data.frame(IID=data[,'IID'],PD=FALSE)
na_catcher <- data.frame(IID=data[,'IID'],na=TRUE)

for (field in c(
    "f.20110.0.0", "f.20110.0.1", "f.20110.0.2", "f.20110.0.3", "f.20110.0.4", "f.20110.0.5", "f.20110.0.6", "f.20110.0.7", "f.20110.0.8", "f.20110.0.9", "f.20110.0.10", 
    "f.20110.1.0", "f.20110.1.1", "f.20110.1.2", "f.20110.1.3", "f.20110.1.4", "f.20110.1.5", "f.20110.1.6", "f.20110.1.7", "f.20110.1.8", "f.20110.1.9", "f.20110.1.10", 
    "f.20110.2.0", "f.20110.2.1", "f.20110.2.2", "f.20110.2.3", "f.20110.2.4", "f.20110.2.5", "f.20110.2.6", "f.20110.2.7", "f.20110.2.8", "f.20110.2.9", "f.20110.2.10", 
    "f.20110.3.0", "f.20110.3.1", "f.20110.3.2", "f.20110.3.3", "f.20110.3.4", "f.20110.3.5", "f.20110.3.6", "f.20110.3.7", "f.20110.3.8", "f.20110.3.9", "f.20110.3.10"
)) {
    temp <- (data[,..field] == 11)
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

na_catcher$na[na_catcher$na==TRUE] <- NA


subdata[,'P2_STATUS'] <- as.integer(PD_catcher$PD | na_catcher$na)

# %%
working_total <- data.frame(IID=data[,'IID'],siblings=NA)

temp_df <- data[,c(
    "IID",
    "f.1873.0.0", "f.1873.1.0", "f.1873.2.0", "f.1873.3.0",
    "f.1883.0.0", "f.1883.1.0", "f.1883.2.0", "f.1883.3.0"
)]
brothers <- temp_df[,1]
sisters <- temp_df[,1]
brothers[!is.na(temp_df$f.1873.0.0),"num"] <- apply(temp_df[!is.na(temp_df$f.1873.0.0),c("f.1873.0.0", "f.1873.1.0", "f.1873.2.0", "f.1873.3.0")], 1, function(x) max(x[!is.na(x)]))
sisters[!is.na(temp_df$f.1883.0.0),"num"] <- apply(temp_df[!is.na(temp_df$f.1883.0.0),c("f.1883.0.0", "f.1883.1.0", "f.1883.2.0", "f.1883.3.0")], 1, function(x) max(x[!is.na(x)]))
total_siblings <- brothers$num + sisters$num


subdata[,'NUM_SIBS'] <- total_siblings

# %%
iteration_1 <- TRUE
PD_catcher <- data.frame(IID=data[,'IID'],PD=FALSE)
na_catcher <- data.frame(IID=data[,'IID'],na=TRUE)

for (field in c(
    "f.20111.0.0", "f.20111.0.1", "f.20111.0.2", "f.20111.0.3", "f.20111.0.4", "f.20111.0.5", "f.20111.0.6", "f.20111.0.7", "f.20111.0.8", "f.20111.0.9", "f.20111.0.10", "f.20111.0.11", 
    "f.20111.1.0", "f.20111.1.1", "f.20111.1.2", "f.20111.1.3", "f.20111.1.4", "f.20111.1.5", "f.20111.1.6", "f.20111.1.7", "f.20111.1.8", "f.20111.1.9", "f.20111.1.10", "f.20111.1.11", 
    "f.20111.2.0", "f.20111.2.1", "f.20111.2.2", "f.20111.2.3", "f.20111.2.4", "f.20111.2.5", "f.20111.2.6", "f.20111.2.7", "f.20111.2.8", "f.20111.2.9", "f.20111.2.10", "f.20111.2.11", 
    "f.20111.3.0", "f.20111.3.1", "f.20111.3.2", "f.20111.3.3", "f.20111.3.4", "f.20111.3.5", "f.20111.3.6", "f.20111.3.7", "f.20111.3.8", "f.20111.3.9", "f.20111.3.10", "f.20111.3.11"
)) {
    temp <- (data[, ..field] == 11)
    temp[is.na(temp)] <- FALSE
    PD_catcher$PD <- PD_catcher$PD | temp
    
    temp1 <- (data[,..field] < 0)
    temp2 <- is.na(data[,..field])
    temp1[is.na(temp)] <- FALSE
    temp2[is.na(temp)] <- FALSE
    temp <- temp1 | temp2
    na_catcher$na <- na_catcher$na & temp
}

na_catcher$na[na_catcher$na==TRUE] <- NA


subdata[,'SIB_STATUS'] <- as.integer(PD_catcher$PD | na_catcher$na)

# %%
subdata
# Out:
#        IID     CHILD_STATUS P1_STATUS P2_STATUS NUM_SIBS SIB_STATUS
# 1      1000011  0           NA        NA         2       NA
# 2      1000026 NA            0         0         0       NA
# 3      1000032  0            1         0         2       NA
# 4      1000044  0           NA         0         1        0
# 5      1000058  0            0        NA         2        0
# 6      1000060  0            0        NA         0       NA
# 7      1000075 NA            0        NA         2       NA
# 8      1000083  0           NA         0         2        0
# 9      1000097  0           NA         0         4        0
# 10     1000102  0            0         0         3       NA
# 11     1000116 NA            0         0         2       NA
# 12     1000121  0           NA         0         1       NA
# 13     1000139  0            0        NA         1       NA
# 14     1000143  0           NA        NA        NA       NA
# 15     1000150  0            0         0         2       NA
# ...

# %%
subdata <- data.frame(subdata)

# %%
result = create_pheno(
    data=subdata,
    trait_h2=0.34,
    T_val_child=qnorm(mean(subdata[,'CHILD_STATUS'],na.rm=T),lower.tail = FALSE),
    T_val_parent=qnorm(mean(c(subdata[,'P1_STATUS'],subdata[,'P2_STATUS']),na.rm=T),lower.tail = FALSE),
    relevant_trait_child='CHILD_STATUS',
    relevant_trait_dad='P1_STATUS',
    relevant_trait_mom='P2_STATUS',
    number_siblings_col='NUM_SIBS',
    relevant_trait_sib='SIB_STATUS',
    maximum_siblings_to_compute=10
)

# %%
result_df <- data.table(result)
names(result_df) <- c('IID','ltfh_cc','ltfh_nosib','ltfh')
result_df$IID <- as.character(result_df$IID)

# %%
names(result_df) <- c('pejID','ltfh_cc','ltfh_nosib','ltfh')
matching = read.csv('/mnt/stsi/stsi1/ptseng/UKBB_Resources/phenos/matched_torkamani_pejman_ids.txt',sep='\t')
names(matching) <- c('torkID','pejID')

# %%
output = merge(result_df,matching,by='pejID',all=TRUE)
output = output[output$torkID != 'f.eid',c('torkID','torkID','ltfh')]

# %%
names(output) <- c('FID','IID','ltfh')

# %%
output$FID <- as.integer(output$FID)
output$IID <- as.integer(output$IID)

# %%
fwrite(output,'../regenie_input/PD_ltfh.txt',sep=' ',na='NA',quote=FALSE)

# %%
output <- fread("../regenie_input/PD_ltfh.txt")

# %%
print(max(output$ltfh[!is.na(output$ltfh)]))
print(min(output$ltfh[!is.na(output$ltfh)]))
# Out:
# [1] 1.575411
# [1] -0.05563296

# %%
print(length(output[output$ltfh>0,]$IID)/length(output$IID))
# Out:
# [1] 0.04672338

# %%
subdata <- data.table(subdata)
names(matching) <- c('torkID','IID')
names(result_df) <- c('IID','ltfh_cc','ltfh_nosib','ltfh')
composite <- merge(matching,subdata)
composite <- merge(composite,result_df[,c('IID','ltfh')])
composite <- data.table(composite)

# %%
composite[!is.finite(composite$ltfh),]
# Out:
#      IID     torkID  CHILD_STATUS P1_STATUS P2_STATUS NUM_SIBS SIB_STATUS ltfh
# 1    1000787 2022811 NA           NA        NA         1       NA         NA
# 2    1002664 5004915 NA           NA        NA        NA       NA         NA
# 3    1002849 4112949 NA           NA        NA         8       NA         NA
# 4    1003219 1968401 NA           NA        NA         0       NA         NA
# 5    1003543 5278921 NA           NA        NA        NA       NA         NA
# 6    1005322 2146674 NA           NA        NA         0       NA         NA
# 7    1005487 3393044 NA           NA        NA         2       NA         NA
# 8    1006808 3211519 NA           NA        NA         1       NA         NA
# 9    1006934 5490734 NA           NA        NA         4       NA         NA
# 10   1008558 2056777 NA           NA        NA         1       NA         NA
# 11   1009093 2939647 NA           NA        NA         0       NA         NA
# ...

# %%
composite
# Out:
#        IID     torkID  CHILD_STATUS P1_STATUS P2_STATUS NUM_SIBS SIB_STATUS
# 1      1000011 3267059  0           NA        NA         2       NA
# 2      1000026 4406597 NA            0         0         0       NA
# 3      1000032 2438420  0            1         0         2       NA
# 4      1000044 5753871  0           NA         0         1        0
# 5      1000058 3391516  0            0        NA         2        0
# 6      1000060 2286014  0            0        NA         0       NA
# 7      1000075 3715820 NA            0        NA         2       NA
# 8      1000083 5759422  0           NA         0         2        0
# 9      1000097 5797149  0           NA         0         4        0
# 10     1000102 4912463  0            0         0         3       NA
# 11     1000116 5145070 NA            0         0         2       NA
# 12     1000121 3102312  0           NA         0         1       NA
# 13     1000139 3005926  0            0        NA         1       NA
# ...

# %%
composite[composite$IID == 6023333]
# Out:
#   IID     torkID  CHILD_STATUS P1_STATUS P2_STATUS NUM_SIBS SIB_STATUS ltfh
# 1 6023333 4885865 NA           NA        NA        1        NA         NA

# %%
length(output$IID)
# Out:
# [1] 501141

# %%
output[is.na(output$ltfh)]
# Out:
#      FID     IID     ltfh
# 1    2022811 2022811 NA
# 2    5004915 5004915 NA
# 3    4112949 4112949 NA
# 4    1968401 1968401 NA
# 5    5278921 5278921 NA
# 6    2146674 2146674 NA
# 7    3393044 3393044 NA
# 8    3211519 3211519 NA
# 9    5490734 5490734 NA
# 10   2056777 2056777 NA
# 11   2939647 2939647 NA
# 12   1412463 1412463 NA
# 13   3533431 3533431 NA
# 14   1832064 1832064 NA
# 15   3287880 3287880 NA
# 16   1631542 1631542 NA
# 17   4691716 4691716 NA
# 18   1240606 1240606 NA
# 19   4017711 4017711 NA
# 20   2489823 2489823 NA
# 21   3318663 3318663 NA
# 22   1800138 1800138 NA
# 23   2787779 2787779 NA
# 24   3422872 3422872 NA
# 25   5682696 5682696 NA
# 26   1668733 1668733 NA
# 27   5855355 5855355 NA
# 28   3878886 3878886 NA
# 29   1880149 1880149 NA
# 30   2655831 2655831 NA
# ⋮    ⋮       ⋮       ⋮
# 7153 2938801 2938801 NA
# 7154 5836912 5836912 NA
# 7155 1284383 1284383 NA
# 7156 3658720 3658720 NA
# 7157 5060788 5060788 NA
# 7158 5537233 5537233 NA
# ...
